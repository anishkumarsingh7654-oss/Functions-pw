# %% [markdown]
# # Functions

# %% [markdown]
# 1. what is the difference betwen a function and a method in python?
#    - a function is the important and can be called from anywere, while a method is tied to a class or object and must be caleed on that object or within the class.
#    2. second question
#    - asdfjkl;

# %% [markdown]
# #Questions

# %%
# question
...
this is an example
...
